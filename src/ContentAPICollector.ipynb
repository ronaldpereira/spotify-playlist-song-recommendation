# %%
import json
import time
import os
import numpy as np
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from tqdm import tqdm_notebook

# %%
def json_reader(begin):
    if begin not in np.arange(0, 11000, 1000):
        raise Exception(
            "Invalid start pid! Start pids must be {0, 1000, 2000, ..., 999000}"
        )

    end = begin + 1000
    path = (
        "../data/playlists/playlist.slice." + str(begin) + "-" + str(end - 1) + ".json"
    )

    jsonData = json.load(open(path, "r"))
    actualSlice = pd.DataFrame.from_dict(jsonData["playlists"], orient="columns")
    return actualSlice

# %%
jsonList = []
for begin in np.arange(0, 11000, 1000):
    actual = json_reader(begin)
    jsonList.append(actual)

trainData = pd.concat(jsonList)
jsonList.clear()

print(trainData.shape)
trainData.head()
# Out:
# (11000, 12)
#   collaborative description  duration_ms  modified_at              name  \
# 0         false         NaN     11532414   1493424000        Throwbacks
# 1         false         NaN     11656470   1506556800  Awesome Playlist
# 2         false         NaN     14039958   1505692800           korean
# 3         false         NaN     28926058   1501027200               mat
# 4         false         NaN      4335282   1401667200               90s
#
#    num_albums  num_artists  num_edits  num_followers  num_tracks  pid  \
# 0          47           37          6              1          52    0
# 1          23           21          5              1          39    1
# 2          51           31         18              1          64    2
# 3         107           86          4              1         126    3
# 4          16           16          7              2          17    4
#
#                                               tracks
# 0  [{'pos': 0, 'artist_name': 'Missy Elliott', 't...
# 1  [{'pos': 0, 'artist_name': 'Survivor', 'track_...
# 2  [{'pos': 0, 'artist_name': 'Hoody', 'track_uri...
# 3  [{'pos': 0, 'artist_name': 'Camille Saint-Saën...
# 4  [{'pos': 0, 'artist_name': 'The Smashing Pumpk...

# %%
# Turn playlist level dataframe into song level dataframe
# is a df of all track ids, cooresponding artist names, track names and playlist ids

songPlaylistArray = []
for index, row in trainData.iterrows():
    for track in row["tracks"]:
        songPlaylistArray.append(
            [track["track_uri"], track["artist_name"], track["track_name"], row["pid"]]
        )
songPlaylist = pd.DataFrame(
    songPlaylistArray, columns=["trackid", "artist_name", "track_name", "pid"]
)

print(songPlaylist.shape)
songPlaylist.head(10)
# Out:
# (731360, 4)
#                                 trackid         artist_name  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI       Missy Elliott
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak      Britney Spears
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv             Beyoncé
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT   Justin Timberlake
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H              Shaggy
# 5  spotify:track:0XUfyU2QviPAs6bxSpXYG4               Usher
# 6  spotify:track:68vgtRHr7iZHpzGpon6Jlo               Usher
# 7  spotify:track:3BxWKCI06eQ5Od8TY2JBeA  The Pussycat Dolls
# 8  spotify:track:7H6ev70Weq6DdpZyyTmUXk     Destiny's Child
# 9  spotify:track:2PpruBYCo4H7WOBJ7Q2EwM             OutKast
#
#                                    track_name  pid
# 0  Lose Control (feat. Ciara & Fat Man Scoop)    0
# 1                                       Toxic    0
# 2                               Crazy In Love    0
# 3                              Rock Your Body    0
# 4                                It Wasn't Me    0
# 5                                       Yeah!    0
# 6                                      My Boo    0
# 7                                     Buttons    0
# 8                                 Say My Name    0
# 9              Hey Ya! - Radio Mix / Club Mix    0

# %%
trackids = songPlaylist["trackid"]
print(trackids)
# Out:
# 0         spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1         spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2         spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3         spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4         spotify:track:1lzr43nnXAijIGYnCT8M8H
# 5         spotify:track:0XUfyU2QviPAs6bxSpXYG4
# 6         spotify:track:68vgtRHr7iZHpzGpon6Jlo
# 7         spotify:track:3BxWKCI06eQ5Od8TY2JBeA
# 8         spotify:track:7H6ev70Weq6DdpZyyTmUXk
# 9         spotify:track:2PpruBYCo4H7WOBJ7Q2EwM
# 10        spotify:track:2gam98EZKrF9XuOkU13ApN
# 11        spotify:track:4Y45aqo9QMa57rDsAJv40A
# 12        spotify:track:1HwpWwa6bnqqRhK8agG4RS
# 13        spotify:track:20ORwCJusz4KS2PbTPVNKo
# 14        spotify:track:7k6IzwMGpxnRghE7YosnXT
# 15        spotify:track:1Bv0Yl01xBDZD4OQP93fyl
# 16        spotify:track:4omisSlTk6Dsq2iQD7MA07
# 17        spotify:track:7xYnUQigPoIDAMPVK79NEq
# 18        spotify:track:6d8A5sAx9TfdeseDvfWNHd
# 19        spotify:track:4pmc2AxSEq6g7hPVlJCPyP
# 20        spotify:track:215JYyyUnrJ98NK3KEwu6d
# 21        spotify:track:0uqPG793dkDDN7sCUJJIVC
# 22        spotify:track:19Js5ypV6JKn4DMExHQbGc
# 23        spotify:track:1JURww012QnWAw0zZXi6Aa
# 24        spotify:track:7DFnq8FYhHMCylykf6ZCxA
# 25        spotify:track:1TfAhjzRBWzYZ8IdUV3igl
# 26        spotify:track:1Y4ZdPOOgCUhBcKZOrUFiS
# 27        spotify:track:6MjljecHzHelUDismyKkba
# 28        spotify:track:67T6l4q3zVjC5nZZPXByU8
# 29        spotify:track:34ceTg8ChN5HjrqiIYCn9Q
#                           ...
# 731330    spotify:track:3V3iy4K6paycRmTyrjQVwi
# 731331    spotify:track:1uXbwHHfgsXcUKfSZw5ZJ0
# 731332    spotify:track:17dtO7OkVT3fpzGAaghHH5
# 731333    spotify:track:388jD8ko9cvFM9cd9TYDrl
# 731334    spotify:track:0MGlHpo9P4HN4AsgG44GG7
# 731335    spotify:track:5lUp6n9vv3aDkvamXVBuak
# 731336    spotify:track:5EnYT6F7wEcdege6mDHEfO
# 731337    spotify:track:7CEdx5ewzN3SWScQZ1SC2q
# 731338    spotify:track:3Np3DKcOQuraKONOVVMxGJ
# 731339    spotify:track:1SwFjpaMTyOGxz82WdjerB
# 731340    spotify:track:7seTcUFOhn5caSDbiSfsp0
# 731341    spotify:track:6CDaYzCjahDKqFAIslpveh
# 731342    spotify:track:3eo7KxA5x2gMngBpyhcO1X
# 731343    spotify:track:0ntQJM78wzOLVeCUAW7Y45
# 731344    spotify:track:51LIqkda3pTeECZUhMnool
# 731345    spotify:track:75Q69chmd8CEZbVsA4CDMm
# 731346    spotify:track:2LRj8su5PjrGkbp3TZZG8D
# 731347    spotify:track:2e3OgIbfZw5deCjLMGatSS
# 731348    spotify:track:6ptJ3y9QvcFgoH7eJIQDf3
# 731349    spotify:track:5LKXxwgll43fxe1lPF7sze
# 731350    spotify:track:38yBBH2jacvDxrznF7h08J
# 731351    spotify:track:4iLqG9SeJSnt0cSPICSjxv
# 731352    spotify:track:270aLuFCbX32hhBr8MQyPM
# 731353    spotify:track:0c6DDLA4rsGGNXWZM5oZdS
# 731354    spotify:track:4MV4wa3Dke1GMBtk06GMR0
# 731355    spotify:track:7zFXmv6vqI4qOt4yGf3jYZ
# 731356    spotify:track:7j56HrjR9cGzvekvZY3Faz
# 731357    spotify:track:6EpRaXYhGOB3fj4V2uDkMJ
# 731358    spotify:track:07cDm2mEYe7KHCHjKYSGdU
# 731359    spotify:track:6rvjjyTCbuoIucuI9TvTfX
# Name: trackid, Length: 731360, dtype: object

# %%
with open(".spotifyTokens", "r") as tokens:
    client_id = tokens.readline().strip()
    client_secret = tokens.readline().strip()

# %%
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

slice = -1
batch_size = 100
for i in tqdm_notebook(range(0, len(trackids), batch_size), ascii=True, desc="Getting Musics Descriptions"):
    tids = trackids[i : i + batch_size]

    musics = sp.audio_features(tids)

    if i % 1000 == 0:
        slice += 1

        if slice > 0:
            with open(
                "../data/music_contents/content.slice.%s-%s.json"
                % (begin_slice, end_slice),
                "rb+",
            ) as output:
                output.seek(-2, os.SEEK_END)
                output.truncate()

            with open(
                "../data/music_contents/content.slice.%s-%s.json"
                % (begin_slice, end_slice),
                "a",
            ) as output:
                output.write("\n]")

        begin_slice = slice * 1000
        end_slice = begin_slice + 999

        if end_slice > len(trackids):
            end_slice = len(trackids)

        with open(
            "../data/music_contents/content.slice.%s-%s.json"
            % (begin_slice, end_slice),
            "w",
        ) as output:
            output.write("[\n")

    with open(
        "../data/music_contents/content.slice.%s-%s.json" % (begin_slice, end_slice),
        "a",
    ) as output:
        for music in musics:
            output.write(json.dumps(music, indent=4))
            output.write(",\n")
            
with open(
    "../data/music_contents/content.slice.%s-%s.json" % (begin_slice, end_slice), "rb+"
) as output:
    output.seek(-2, os.SEEK_END)
    output.truncate()

with open(
    "../data/music_contents/content.slice.%s-%s.json" % (begin_slice, end_slice), "a"
) as output:
    output.write("\n]")
# Out:
# HBox(children=(IntProgress(value=0, description='Getting Musics Descriptions', max=7314, style=ProgressStyle(d…

# %%
with open("../data/music_contents/content.slice.0-999.json") as json_file:
    data = json.load(json_file)
    print(len(data))
# Out:
# 1000
